# %%
import sqlite3

# %%
conn = sqlite3.connect("topmentor.sql")

# %%
conn

# %%
import sqlite3

# Connect to database (creates file if not exists)
conn = sqlite3.connect("school.db")

# Create cursor
cursor = conn.cursor()

# Create Student table
cursor.execute("""
CREATE TABLE IF NOT EXISTS student (
    student_id INTEGER PRIMARY KEY,
    name TEXT NOT NULL,
    age INTEGER,
    class TEXT
)
""")

# Create Marks table
cursor.execute("""
CREATE TABLE IF NOT EXISTS marks (
    mark_id INTEGER PRIMARY KEY,
    student_id INTEGER,
    subject TEXT,
    marks INTEGER,
    FOREIGN KEY (student_id) REFERENCES student(student_id)
)
""")

# Save changes
conn.commit()

# Close connection
conn.close()

print("school.db created with student and marks tables successfully.")
# Out:
# school.db created with student and marks tables successfully.

# %%
import sqlite3

# Connect to database
conn = sqlite3.connect("school.db")
cursor = conn.cursor()

# Insert values into student table
cursor.execute("INSERT INTO student VALUES (1, 'Antara', 16, '10th')")
cursor.execute("INSERT INTO student VALUES (2, 'Ravi', 15, '9th')")
cursor.execute("INSERT INTO student VALUES (3, 'Sneha', 17, '11th')")

# Insert values into marks table
cursor.execute("INSERT INTO marks VALUES (1, 1, 'Math', 85)")
cursor.execute("INSERT INTO marks VALUES (2, 1, 'Science', 90)")
cursor.execute("INSERT INTO marks VALUES (3, 2, 'Math', 78)")
cursor.execute("INSERT INTO marks VALUES (4, 3, 'English', 88)")

# Save changes
conn.commit()

# Close connection
conn.close()

print('Data inserted successfully')
# Out:
# Data inserted successfully
