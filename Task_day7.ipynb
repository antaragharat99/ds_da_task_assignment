# %%
name = {"a":1}
print(type(name))
# Out:
# <class 'dict'>

# %%
name = [1,2,3,4]
print(type(name))
# Out:
# <class 'list'>

# %%
name = (1,2,3,4)
print(type(name))
# Out:
# <class 'tuple'>

# %%
num = 1
print(type(num))
# Out:
# <class 'int'>

# %%
name = {1,2,3,4}
print(type(name))
# Out:
# <class 'set'>

# %%
name = [1,2,3,4,3]
print(name)
# Out:
# [1, 2, 3, 4, 3]

# %%
name = {1,2,3,4,3}
print(name)
# Out:
# {1, 2, 3, 4}

# %%
name = (1,2,3,4,3)
print(name)
# Out:
# (1, 2, 3, 4, 3)

# %%
a1 = (1,2,3)
a2 = (7,3,6)
print(a1 + a2)
# Out:
# (1, 2, 3, 7, 3, 6)

# %%
a1 = (1,2,3) * 2
print(a1)
# Out:
# (1, 2, 3, 1, 2, 3)

# %%
a1 = (1,2,3) * 5
print(a1)
# Out:
# (1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3)

# %%
fruits = ("apple","banana","mango","grape","cherry")
print(fruits[0:6:2])
# Out:
# ('apple', 'mango', 'cherry')

# %%
fruits = ("apple","banana","mango","grape","cherry")
fruits.index("mango")
# Out:
# 2

# %%
fruits = ("apple","banana","mango","grape","cherry")
for f in fruits:
  print(f)
# Out:
# apple
# banana
# mango
# grape
# cherry

# %%
fruits = ("apple","banana","mango","grape","cherry","grape","mango","grape")
fruits.count("grape")
# Out:
# 3

# %%
fruits = ("apple","banana","mango","grape","cherry")
print(len(fruits))
# Out:
# 5

# %%
fruits = ("apple","banana","mango","grape","cherry")
y = list(fruits)
y.append("orange")
my_tuple = tuple(y)
print(my_tuple)
# Out:
# ('apple', 'banana', 'mango', 'grape', 'cherry', 'orange')

# %%
fruits = {"apple","banana",2,7,9,9,"mango","grape","cherry"}
print(fruits)
# Out:
# {2, 7, 9, 'grape', 'banana', 'apple', 'cherry', 'mango'}

# %%
a1 = {1,2,3,3}
a2 = {2,7,3,6}
a1.union(a2)
# Out:
# {1, 2, 3, 6, 7}

# %%
a1 = {1,2,3,3}
a2 = {2,7,3,6}
a1.intersection(a2)
# Out:
# {2, 3}

# %%
a1 = {1,2,3,3}
a2 = {2,7,3,6}
a1.difference(a2)
# Out:
# {1}

# %%
a1 = {1,2,3,3}
a1.clear()
print(a1)
# Out:
# set()
