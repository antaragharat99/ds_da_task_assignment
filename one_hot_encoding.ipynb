# %%
import pandas as pd

data = {
    "City": ["Delhi", "Mumbai", "Pune", "Delhi"]
}

df = pd.DataFrame(data)

encoded_df = pd.get_dummies(df, columns=["City"])
print(encoded_df)
# Out:
#    City_Delhi  City_Mumbai  City_Pune
# 0        True        False      False
# 1       False         True      False
# 2       False        False       True
# 3        True        False      False

# %%
from sklearn.preprocessing import OneHotEncoder
import pandas as pd

data = [["Delhi"], ["Mumbai"], ["Pune"]]

encoder = OneHotEncoder(sparse=False)
encoded = encoder.fit_transform(data)

print(encoded)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_16689/1054942980.py in <cell line: 0>()
#       4 data = [["Delhi"], ["Mumbai"], ["Pune"]]
#       5
# ----> 6 encoder = OneHotEncoder(sparse=False)
#       7 encoded = encoder.fit_transform(data)
#       8
#
# TypeError: OneHotEncoder.__init__() got an unexpected keyword argument 'sparse'

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import numpy as np

# Data
X = np.array([[1,0],[1,1],[0,0],[0,1]])
y = np.array([1,1,0,0])

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# Model
model = GaussianNB()
model.fit(X_train, y_train)

# Prediction
y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0
