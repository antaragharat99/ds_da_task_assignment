# %%
input = "topmentor"
print(input[::-1])
# Out:
# rotnempot

# %%
text = "Antara live in thane"
print(text[0],text.split()[1][0],"in thane")
# Out:
# A l in thane

# %%
name = {"Name":"Antara","City":"Thane","Education":"B.E"}
print(name["Name"])
# Out:
# Antara

# %%
name = {"name":"Antara","city":"Thane","education":"B.E"}
print(name)
# Out:
# {'name': 'Antara', 'city': 'Thane', 'education': 'B.E'}

# %%
name.pop("city")
print(name)
# Out:
# {'name': 'Antara', 'education': 'B.E'}

# %%
for key, value in name.items():
 print(key, ":", value)
# Out:
# name : Antara
# education : B.E

# %%
for i in name:
 print(i)
# Out:
# name
# education

# %%
for i in name:
 print(name[i])
# Out:
# Antara
# B.E

# %%
name.del("name")
print(name)
# Out:
#   File "/tmp/ipykernel_3304/2426971634.py", line 1
#     name.del("name")
#          ^
# SyntaxError: invalid syntax

# %%
name.pop("city")
print(name)
# Out:
# {'name': 'Antara', 'education': 'B.E'}
