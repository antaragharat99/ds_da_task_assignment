# %%
print("Hello")
# Out:
# Hello

# %%
greet = "Welcome Top Mentor"
print(greet)
# Out:
# Welcome Top Mentor

# %%
name = "Dev"
print("Hello",name)
print("How are you",name,". Welcom")
# Out:
# Hello Dev
# How are you Dev . Welcom

# %%
print(1+2)
# Out:
# 3

# %%
print("Wel","Come")
# Out:
# Wel Come

# %%
print("Wel"+"Come")
# Out:
# WelCome

# %%
a = 5
b = 8
print(a+b)
# Out:
# 13

# %%
a= 10
b= 5
print(a*b)
# Out:
# 50

# %%
a= 2
b= 4
c = "2 power of 4"
print(c,"=",a**b)
# Out:
# 2 power of 4 = 16

# %%
name = input("what is your name")
# Out:
# what is your nametest

# %%
name = input("what is your name")
print("Hello",name)
# Out:
# what is your nametest
# Hello test

# %%
name = input("Enter your name")
print("Hello",name)
# Out:
# Enter your nametest
# Hello test

# %%
price = 99.99
print(price)
# Out:
# 99.99

# %%
a = input("Enter first number: ")
b = input("Enter second number: ")
print(a+b)
# Out:
# Enter first number: 10
# Enter second number: 12
# 1012

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
print(a+b)
# Out:
# Enter first number: 23
# Enter second number: 34
# 57

# %%
is_valid = True
print(is_valid)
# Out:
# True

# %%
name = "Antara"
print(name)
# Out:
# Antara

# %%
a = 5
b = 8
print(a+b)
# Out:
# 13

# %%
x, y, z = 10, 20, 30
print(x, y, z)
# Out:
# 10 20 30

# %%
p = q = r = 100
print(p, q, r)
# Out:
# 100 100 100

# %%
age = 25
print(age)

age = 30
print(age)
# Out:
# 25
# 30

# %%
num = 50
del num
print(num)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_569/3346981391.py in <cell line: 0>()
#       1 num = 50
#       2 del num
# ----> 3 print(num)
#
# NameError: name 'num' is not defined

# %%
message = "Welcome TopMentor"
print(len(message))

# %%
data = 100
print(data)
print(data + data)

data = str(data)
print(data)
print(data + data)
