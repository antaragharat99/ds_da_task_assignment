# %%
install streamlit as st
st.title("Hello, Streamlit!")
name = st.text_input("Enter your name")

if.name:
  st.write("Welcome",name)
# Out:
#   File "/tmp/ipykernel_20155/2637526174.py", line 1
#     install streamlit as st
#             ^
# SyntaxError: invalid syntax
