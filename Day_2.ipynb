# %%
#find intersest rate & total amount
p = 2000
r = 20
t = 2

rate = (p*t*r)/100
total = rate + p
print("Interset amount: ",rate)
print("Total amount: ", total)
# Out:
# Interset amount:  800.0
# Total amount:  2800.0

# %%
# Area of rectangle
length = 50
width = 60
area = length * width
print("Area of rectangle: ",area)
# Out:
# Area of rectangle:  3000

# %%
#find area of circle
pi = 3.14
r = 7
area = pi * r * r
print("Area of circle: ",area)
# Out:
# Area of circle:  153.86

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")
country = input("Enter your country: ")
print("Hello",name,"Your age is",age,"and you are from",country,".")
# Out:
# Enter your name: antara
# Enter your age: 30
# Enter your country: India
# Hello antara Your age is 30 and you are from India .

# %%
clg = input("Enter your clg: ")
print(name,"is from",clg)
# Out:
# Enter your clg: Mumbai
# antara is from Mumbai

# %%
age = int(input("Enter your age: "))
if age > 18 :
  print("You can give the vote.")
else:
  print("You cannot give the vote.")
# Out:
# Enter your age: 14
# You cannot give the vote.

# %%
age = int(input("Enter your age: "))
if age >= 18 :
  print("You can vote!")
else:
  print("You are too young to vote")

# %%
age = int(input("Enter your age: "))
country = input("Enter your country: ")
if age >= 18 :
  if country == "India" :
    print("You can give the vote.")
  else :
    print("You cannot give the vote.")
else:
  print("You are too young to vote")
# Out:
# Enter your age: 34
# Enter your country: India
# You can give the vote.

# %%
num = int(input("Enter number: "))

if num == 1 :
  print("ONE")
elif num == 2:
  print("TWO")
elif num == 3:
  print("THREE")
# Out:
# Enter number: 2
# TWO

# %%
temp = int(input("Enter current temprature: "))

if temp < 25 :
  print("It is cold")
else :
  print("It is hot outside")
# Out:
# Enter current temprature: 24
# It is cold

# %%
temp = int(input("Enter current temprature: "))

if temp <= 14 :
  print("It is cold")
elif temp >= 15 and temp <= 21:
  print("It is moderate")
else :
  print("It is hot outside")

# %%
print(temp>25)

# %%
num = int(input("Enter a number: "))

if num > 0:
    print("Positive Number")

# %%
num = int(input("Enter a number: "))
print("Even" if num % 2 == 0 else "Odd")

# %%
x = 10
if x == 10: print("Python is cool")

# %%
num = int(input("Enter a number: "))

if num > 0:
    if num % 2 == 0:
        print("Positive and Even")

# %%
num = int(input("Enter a number: "))

if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")

# %%
text = input("Enter a string: ")

if "Python" in text:
    print("Python found")

# %%
num = int(input("Enter a number: "))

if num % 3 == 0 and num % 5 == 0:
    print("Divisible by both 3 and 5")
else:
    print("Not divisible by both 3 and 5")

# %%
year = int(input("Enter a year: "))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("Leap Year")
else:
    print("Not a Leap Year")

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
print(a % b)

# %%
print(10 > 5)

# %%
a = 10
b = 10

if a == b:
    print("Both values are equal")

# %%
if 10 > 5 and 20 > 15:
    print("Both conditions are True")

# %%
x = 10
x += 5
print(x)

# %%
num = int(input("Enter a number: "))

if not (num > 100):
    print("Number is not greater than 100")

# %%
for i in range(1, 11):
    print(i * 5)

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
print(a / b)

# %%
a = 10
b = 5

a = a + b
b = a - b
a = a - b

print("a =", a)
print("b =", b)

# %%
print("Python", "is", "fun", sep="-")

# %%
print("Hello", end=" ")
print("World")

# %%
print("Python " + "is " + "awesome!")

# %%
name = "Antara"
age = 30
print(f"My name is {name} and I am {age} years old.")

# %%
a = 10
b = 5
print("Sum =", a + b)

# %%
print("Python is named after Monty Python, not the snake!")
